# %% [markdown]
# <a href="https://colab.research.google.com/github/silvishVictmori/Apache-Spark-Setup/blob/main/pandas3_2_mongo_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# remove old spark installations if needed
# !rm -dr spark*
# Out:
# rm: cannot remove 'spark*': No such file or directory

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.2.0/spark-3.2.0-bin-hadoop2.7.tgz
# !wget -q https://downloads.apache.org/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# !tar xf spark-3.2.1-bin-hadoop2.7.tgz
# !tar xf spark-3.2.1-bin-hadoop3.2.tgz

# %%
# !ls /content/
# Out:
# drive  sample_data  spark-3.2.1-bin-hadoop3.2  spark-3.2.1-bin-hadoop3.2.tgz

# %%
# !pip install -q findspark
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.2.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 37 kB/s
# Collecting py4j==0.10.9.3
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 50.5 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=f18bd744bf5cf0cda7e36765b91fc81d7269fbde9684b9792b65e6526d3f0e5d
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.3 pyspark-3.2.1

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# os.environ["SPARK_HOME"] = "/content/spark-3.2-bin-hadoop3.2"
os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop3.2"

# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java

# !java -version
# !python --version
# Out:
# openjdk version "11.0.13" 2021-10-19
# OpenJDK Runtime Environment (build 11.0.13+8-Ubuntu-0ubuntu1.18.04)
# OpenJDK 64-Bit Server VM (build 11.0.13+8-Ubuntu-0ubuntu1.18.04, mixed mode, sharing)
# Python 3.7.12

# %%
import findspark
#findspark.init("/content/spark-2.4.4-bin-hadoop2.7")
findspark.init()

# %%
os.environ["SPARK_HOME"]

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('SparkWithPostgres')\
        .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.0")\
        .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://272aebe8e716:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SparkWithPostgres</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = spark.read.format("com.mongodb.spark.sql.DefaultSource").option("spark.mongodb.input.uri","mongodb://username:password@13.40.61.62:27017/datbasename.collection_name").load()

# %%
data.printSchema()
# Out:
# root

# %%
data.show()
# Out:
# ++
# ||
# ++
# ++

# %%
df.count()
# Out:
# 0
